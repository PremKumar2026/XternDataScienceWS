# %%
import pandas as pd
import numpy as np
import os
import googlemaps
import gmaps
from pprint import pprint
import openrouteservice
from ipywidgets.embed import embed_minimal_html
import time
import folium
import requests
import geopy
from geopy.geocoders import Nominatim
import selenium
import time

# %%
GMAP_API_KEY = 'AIzaSyBp_A1esZN7jXv3Oe3nOPxAhL52KurwEgA'
map_client = googlemaps.Client(GMAP_API_KEY)

# %%
ORS_API_KEY = '5b3ce3597851110001cf62484a6dd46a686a4f1384406eba8a47ddce'
or_client = openrouteservice.Client(key = ORS_API_KEY)

# %%
SEARCH_QUERY = "food truck indianapolis"
result_list = []

# %%
response = map_client.places(query=SEARCH_QUERY)
pg2_token = response['next_page_token']
result = response.get('results')

# %%
response = map_client.places(query=SEARCH_QUERY)
results = response.get('results', [])

# check if 'next_page_token' exists in the response and get more results if it does
if 'next_page_token' in response:
    pg2_token = response['next_page_token']
    time.sleep(2)  # To ensure there's a delay before the next request, as required by the API
    response2 = map_client.places(page_token=pg2_token)
    results.extend(response2.get('results', []))
    if 'next_page_token' in response2:  # if there's a third page
        pg3_token = response2['next_page_token']
        time.sleep(2)
        response3 = map_client.places(page_token=pg3_token)
        results.extend(response3.get('results', []))

result_list.extend(results)

# %%
def get_sat_hours(all_hours):
    for i in range(len(all_hours)):
        day = all_hours[i]['close']['day']
        if day == 5:
            sat_open = military_to_us(int(all_hours[i]['open']['time']))
            sat_close = military_to_us(int(all_hours[i]['close']['time']))
        else:
            continue
    return sat_open, sat_close
def get_sun_hours(all_hours):
    for i in range(len(all_hours)):
        day = all_hours[i]['close']['day']
        if day == 6:
            sun_open = military_to_us(int(all_hours[i]['open']['time']))
            sun_close = military_to_us(int(all_hours[i]['close']['time']))
        else:
            continue
    return sun_open, sun_close
def military_to_us(time):
    mark = 'AM'
    if str(time) == '0':
        return '12:00AM'
    if time == 1200:
        return '12:00PM'
    if time>1200:
        time = time - 1200
        mark = 'PM'
    if time >= 1000:
        time = str(time)[:2] + ":" + str(time)[2:] + mark
    else:
        time = str(time)[:1] + ":" + str(time)[1:] + mark
    return time

# %%
names = [] # name of food truck
address = [] # address of food truck
ratings = [] # rating out of 5 
saturday_oc = [] # open or closed on saturday
sunday_oc = [] # open or closed on sunday
sat_open = [] # open hours for saturday if open
sat_close = [] # close hours for saturday if open
sun_open = [] # open hours for sunday if open
sun_close = [] # close hours for sunday if open
urls = [] # food truck website, if they don't have a website google maps url is used
bus_status = [] # operational, temporarily closed
serve_beer = [] # True/false
serve_wine = [] # True/false
serve_lunch = [] # True/false
serve_dinner = [] # True/false
latitude = [] # latitude for food truck location
longitude = [] # longitude for food truck location
# loop through each result from original API call to create lists with desired information for each result
for result in result_list:
    names.append(result.get('name', 'n/a'))
    address.append(result.get('formatted_address', 'n/a'))
    ratings.append(result.get('rating', 'n/a'))
    latitude.append(result['geometry']['location'].get('lat', 'n/a'))
    longitude.append(result['geometry']['location'].get('lng', 'n/a'))

    place_id = result.get('place_id')
    if place_id:
        place_details = map_client.place(place_id)
        details_results = place_details.get('result', {})

        # Example: Fetching business status
        bus_status.append(details_results.get('business_status', 'n/a'))
        try:
            serve_beer.append(details_results['serves_beer'])
        except:
            serve_beer.append('n/a')
        try:
            serve_dinner.append(details_results['serves_dinner'])
        except:
            serve_dinner.append('n/a')
        try:
            serve_lunch.append(details_results['serves_lunch'])
        except:
            serve_lunch.append('n/a')
        try:
            serve_wine.append(details_results['serves_wine'])
        except:
            serve_wine.append('n/a')
            
        try:
            if (details_results['opening_hours']['weekday_text'][5] == "Saturday: Closed"):
                saturday_oc.append("Closed")
                sat_open.append("Closed")
                sat_close.append("Closed")
            else:
                sat_hours = get_sat_hours(details_results['opening_hours']['periods'])
                saturday_oc.append("Open")
                sat_open.append(sat_hours[0])
                sat_close.append(sat_hours[1])
            if (details_results['opening_hours']['weekday_text'][6] == "Sunday: Closed"):
                sunday_oc.append("Closed")
                sun_open.append("Closed")
                sun_close.append("Closed")
            else:
                sun_hours = get_sat_hours(details_results['opening_hours']['periods'])
                sunday_oc.append("Open")
                sun_open.append(sun_hours[0])
                sun_close.append(sun_hours[1])
        except:
            saturday_oc.append('n/a')
            sunday_oc.append('n/a')
            sat_open.append("n/a")
            sat_close.append("n/a")
            sun_open.append("n/a")
            sun_close.append("n/a")
        try: 
            url = details_results['website']
            urls.append(url)
        except:
            urls.append(details_results['url'])
# puts lists into dictionary for easy conversion to dataframe
food_truck_dict = {'name': names, 'address': address, 'rating':ratings, 'sat_open': saturday_oc, 'sun_open':sunday_oc, 'sat_open_hr':sat_open, 'sat_close_hr':sat_close, 
                   'sun_open_hr': sun_open, 'sun_close_hr': sun_close, 'serve_lunch': serve_lunch, 'serve_dinner': serve_dinner, 'serve_beer': serve_beer, 'serve_wine': serve_wine,
                   'website_url':urls, 'business_status': bus_status, 'latitude': latitude, 'longitude': longitude}
# convert the dictionary to a DataFrame.
food_truck_df = pd.DataFrame(food_truck_dict)

# %%
food_truck_df
# Out:
#                                               name  \
# 0                        big Jerry Indy food truck
# 1                         Pico de Gallo Food Truck
# 2                    The Latin Flavor - Food Truck
# 3                    Mi Lindo Pénjamo - Food Truck
# 4                                  Taco food truck
# 5                           Super Tacos food truck
# 6                   Antojitos Guzman food truck #1
# 7                             Emergency Taco Truck
# 8                            Food truck Mil Amores
# 9                                     ClusterTruck
# 10                               FELIX TACOS TRUCK
# 11                    La marina Maxican Food Truck
# 12                            El Viejon Food Truck
# 13                                Oasis Taco Truck
# 14                        The Night Owl Food Truck
# 15                 TACOPOLIS (LA CAPITAL DEL TACO)
# 16                           King gyros food truck
# 17                    El Amigo Taqueria Food Truck
# 18                Taqueria La Autentica Food truck
# 19                        Wild Boar BBQ Food Truck
# 20                             Food Truck Don Luis
# 21                               KG Slider Station
# 22                        Tortas Guicho Food Truck
# 23                        El Buenavista Food Truck
# 24                            Tacos El Iturbidense
# 25                                    Tha Corn Man
# 26                                The Latin Flavor
# 27                                Fiesta on The Go
# 28                         3 Marias Mex Food Truck
# 29                   Juannita's Mexican Food Truck
# 30                               Taste Of Cholulas
# 31                                     Fast-Taco's
# 32                Tacos Tierra caliente Restaurant
# 33                        ClusterTruck - Castleton
# 34                              Restaurante Oaxaca
# 35                                  Indy Food Shop
# 36                T-N-T Hot Dogs & Mobile Catering
# 37                            Kone Heads FoodTruck
# 38                           Birrieria Iturbidense
# 39  Talkin Turkey Real Cajun Food Truck & Catering
# 40                               Taqueria Mi Costa
# 41                     ClusterTruck - Broad Ripple
# 42                           Taqueria El Taco Loco
# 43                                  The Grub House
# 44                          Dogs to Go by Uncle Zo
# 45                    Paco's Taqueria - Food Truck
# 46                                     T'Days Jerk
# 47                            El Pastor Taco Truck
# 48                           Tacos y tortas arroyo
# 49                                     Super Tacos
# 50                                  The Coney Lady
# 51                                         Pi Indy
# 52                                     Tacos Maela
# 53            King Gyro Food Truck- Emerson Avenue
# 54                           Gaucho's Fire Express
# 55                                      Food truck
# 56                             Indy Porkopolis BBQ
# 57                    Ponchitos Mexican Food Truck
# 58                           Everythang & Potatoes
# 59                         MOO & LOU FROZEN TREATS
#
#                                               address  rating sat_open  \
# 0   8522 Madison Ave, Indianapolis, IN 46227, Unit...     5.0     Open
# 1   3014 Lafayette Rd #3000, Indianapolis, IN 4622...     4.5     Open
# 2   9130 E 38th St, Indianapolis, IN 46235, United...     4.1     Open
# 3   7910 Michigan Rd, Indianapolis, IN 46268, Unit...     4.5   Closed
# 4   5621 N Parker Ave, Indianapolis, IN 46220, Uni...     0.0      n/a
# 5   7202 E Washington St, Indianapolis, IN 46219, ...     4.6      n/a
# 6   4853 W 56th St, Indianapolis, IN 46254, United...     3.5     Open
# 7   7001 Pendleton Pike, Indianapolis, IN 46226, U...     4.7      n/a
# 8   5034 E Raymond St, Indianapolis, IN 46203, Uni...     4.0      n/a
# 9   729 N Pennsylvania St, Indianapolis, IN 46204,...     4.8     Open
# 10  3145 W Washington St, Indianapolis, IN 46222, ...     4.5     Open
# 11  7155 Madison Ave, Indianapolis, IN 46227, Unit...     4.0      n/a
# 12  3612 W 30th St, Indianapolis, IN 46222, United...     1.0     Open
# 13  en el parqueadero de Vision Hair salon, 7085 N...     5.0      n/a
# 14  South and, S Meridian St, Indianapolis, IN 462...     5.0     Open
# 15  4857 W 38th St, Indianapolis, IN 46254, United...     4.4      n/a
# 16  4585 S Harding St, Indianapolis, IN 46217, Uni...     4.7     Open
# 17  3356 W 16th St, Indianapolis, IN 46222, United...     4.3     Open
# 18  8801 E 25th St, Indianapolis, IN 46219, United...     3.0     Open
# 19  6129 E Washington St, Indianapolis, IN 46219, ...     5.0      n/a
# 20  3605 Commercial Dr, Indianapolis, IN 46222, Un...     3.0     Open
# 21  3748 Lafayette Rd, Indianapolis, IN 46222, Uni...     5.0     Open
# 22  S. East St and, Fletcher Ave, Indianapolis, IN...     4.5   Closed
# 23  5210 English Ave, Indianapolis, IN 46219, Unit...     5.0     Open
# 24  Circle K Parking Lot, 6402 W 10th St, Indianap...     4.7     Open
# 25  2442 Central Ave, Indianapolis, IN 46205, Unit...     3.8     Open
# 26  9930 E 38th St, Indianapolis, IN 46235, United...     5.0     Open
# 27  2719 E 38th St, Indianapolis, IN 46218, United...     4.0     Open
# 28  3205 E Washington St, Indianapolis, IN 46201, ...     0.0      n/a
# 29  6996 East 21st St, Indianapolis, IN 46219, Uni...     3.0      n/a
# 30  8901-8925 E Washington St, Indianapolis, IN 46...     4.2     Open
# 31  6154 Michigan Rd, Indianapolis, IN 46228, Unit...     4.4     Open
# 32  5035 W Washington St, Indianapolis, IN 46241, ...     4.8     Open
# 33  4737 E 82nd St, Indianapolis, IN 46250, United...     4.9     Open
# 34  5101 W 38th St, Indianapolis, IN 46224, United...     4.5     Open
# 35  9940 E 38th St, Indianapolis, IN 46235, United...     0.0      n/a
# 36  395 E Hanna Ave, Indianapolis, IN 46227, Unite...     5.0   Closed
# 37  7260 Michigan Rd, Indianapolis, IN 46268, Unit...     5.0     Open
# 38  Lot Food Truck, 6302 W Washington St, Indianap...     4.7     Open
# 39  Commercial Kitchen, 4550 Central Ave, Indianap...     0.0      n/a
# 40  1430 W Washington St, Indianapolis, IN 46222, ...     4.3     Open
# 41  2101 E 62nd St, Indianapolis, IN 46220, United...     4.9     Open
# 42  2705 W Washington St, Indianapolis, IN 46222, ...     4.4     Open
# 43  1953 N College Ave, Indianapolis, IN 46202, Un...     4.1     Open
# 44  3376 W 10th St and, N Tibbs Ave, Indianapolis,...     4.3     Open
# 45  6816 E 82nd St, Indianapolis, IN 46250, United...     3.4     Open
# 46  36 E Troy Ave, Indianapolis, IN 46225, United ...     4.4      n/a
# 47     1053997, Indianapolis, IN 46201, United States     4.7      n/a
# 48  2120 W Morris St, Indianapolis, IN 46221, Unit...     5.0     Open
# 49  5653 W Washington St, Indianapolis, IN 46241, ...     4.1   Closed
# 50  3827 N Mitthoefer Rd B13, Indianapolis, IN 462...     4.5      n/a
# 51  1125 E Brookside Ave, Indianapolis, IN 46202, ...     5.0      n/a
# 52  3440 Shadeland Ave, Indianapolis, IN 46226, Un...     4.7     Open
# 53  7140 S Emerson Ave, Indianapolis, IN 46237, Un...     5.0     Open
# 54  906 Carrollton Ave Suite 320, Indianapolis, IN...     4.7     Open
# 55  8801 E 25th St, Indianapolis, IN 46219, United...     5.0     Open
# 56  4225 S East St, Indianapolis, IN 46227, United...     3.9     Open
# 57  3045 English Ave, Indianapolis, IN 46201, Unit...     5.0      n/a
# 58  2442 Central Ave, Indianapolis, IN 46205, Unit...     5.0   Closed
# 59  12125 E 65th St UNIT 36819, Indianapolis, IN 4...     5.0      n/a
#
#    sun_open sat_open_hr sat_close_hr sun_open_hr sun_close_hr serve_lunch  \
# 0    Closed     10:30AM       7:00PM      Closed       Closed        True
# 1      Open      5:00PM       1:00AM      5:00PM       1:00AM        True
# 2      Open     11:00AM      11:00PM     11:00AM      11:00PM        True
# 3    Closed      Closed       Closed      Closed       Closed        True
# 4       n/a         n/a          n/a         n/a          n/a        True
# 5       n/a         n/a          n/a         n/a          n/a        True
# 6      Open      2:00PM       9:30PM      2:00PM       9:30PM        True
# 7       n/a         n/a          n/a         n/a          n/a        True
# 8       n/a         n/a          n/a         n/a          n/a        True
# 9      Open      8:00AM      11:00PM      8:00AM      11:00PM         n/a
# 10     Open      5:00PM      12:00AM      5:00PM      12:00AM         n/a
# 11      n/a         n/a          n/a         n/a          n/a        True
# 12     Open      2:30PM       1:00AM      2:30PM       1:00AM        True
# 13      n/a         n/a          n/a         n/a          n/a        True
# 14     Open      8:30PM       2:30AM      8:30PM       2:30AM         n/a
# 15      n/a         n/a          n/a         n/a          n/a        True
# 16     Open     10:30AM       1:00AM     10:30AM       1:00AM        True
# 17     Open     12:00PM      12:00AM     12:00PM      12:00AM        True
# 18   Closed     12:00PM      11:00PM      Closed       Closed         n/a
# 19      n/a         n/a          n/a         n/a          n/a         n/a
# 20     Open      6:00PM      12:00AM      6:00PM      12:00AM         n/a
# 21     Open     11:00AM      10:00PM     11:00AM      10:00PM        True
# 22   Closed      Closed       Closed      Closed       Closed        True
# 23     Open      1:59PM       4:59AM      1:59PM       4:59AM        True
# 24     Open      6:00PM      12:00AM      6:00PM      12:00AM        True
# 25     Open      3:00PM       9:00PM      3:00PM       9:00PM        True
# 26   Closed     12:00PM      11:00PM      Closed       Closed        True
# 27   Closed      4:00PM      10:00PM      Closed       Closed        True
# 28      n/a         n/a          n/a         n/a          n/a        True
# 29      n/a         n/a          n/a         n/a          n/a        True
# 30     Open      5:00PM      12:00AM      5:00PM      12:00AM        True
# 31     Open      7:00PM       1:00AM      7:00PM       1:00AM        True
# 32   Closed     11:00AM      12:00AM      Closed       Closed        True
# 33   Closed     11:00AM       9:00PM      Closed       Closed        True
# 34   Closed      6:00PM       2:00AM      Closed       Closed        True
# 35      n/a         n/a          n/a         n/a          n/a        True
# 36   Closed      Closed       Closed      Closed       Closed        True
# 37   Closed     12:00PM       9:00PM      Closed       Closed        True
# 38     Open      6:00PM      12:00AM      6:00PM      12:00AM        True
# 39      n/a         n/a          n/a         n/a          n/a         n/a
# 40     Open     11:00AM      11:00PM     11:00AM      11:00PM        True
# 41     Open     10:00AM      11:00PM     10:00AM      11:00PM         n/a
# 42     Open     11:00AM      11:50PM     11:00AM      11:50PM        True
# 43   Closed      8:00AM       6:00PM      Closed       Closed        True
# 44   Closed     10:00AM       5:00PM      Closed       Closed        True
# 45     Open     10:00AM      10:00PM     10:00AM      10:00PM        True
# 46      n/a         n/a          n/a         n/a          n/a         n/a
# 47      n/a         n/a          n/a         n/a          n/a         n/a
# 48     Open      6:00PM      12:00AM      6:00PM      12:00AM       False
# 49   Closed      Closed       Closed      Closed       Closed        True
# 50      n/a         n/a          n/a         n/a          n/a         n/a
# 51      n/a         n/a          n/a         n/a          n/a         n/a
# 52   Closed     11:00AM       8:30PM      Closed       Closed        True
# 53     Open     10:00AM      11:00PM     10:00AM      11:00PM         n/a
# 54     Open     10:00AM      10:00PM     10:00AM      10:00PM        True
# 55   Closed     12:00PM      11:00PM      Closed       Closed         n/a
# 56   Closed     11:00AM       8:00PM      Closed       Closed        True
# 57      n/a         n/a          n/a         n/a          n/a         n/a
# 58   Closed      Closed       Closed      Closed       Closed        True
# 59      n/a         n/a          n/a         n/a          n/a         n/a
#
#    serve_dinner serve_beer serve_wine  \
# 0          True        n/a        n/a
# 1          True      False      False
# 2          True        n/a        n/a
# 3          True        n/a        n/a
# 4          True        n/a        n/a
# 5          True        n/a        n/a
# 6          True        n/a        n/a
# 7          True      False      False
# 8          True        n/a        n/a
# 9           n/a        n/a        n/a
# 10         True      False      False
# 11         True        n/a        n/a
# 12         True        n/a        n/a
# 13         True        n/a        n/a
# 14         True        n/a        n/a
# 15         True      False      False
# 16         True      False      False
# 17         True        n/a        n/a
# 18         True      False        n/a
# 19          n/a        n/a        n/a
# 20          n/a        n/a        n/a
# 21         True      False      False
# 22         True       True      False
# 23         True        n/a        n/a
# 24         True        n/a        n/a
# 25         True      False        n/a
# 26         True        n/a        n/a
# 27         True      False      False
# 28         True        n/a        n/a
# 29         True       True        n/a
# 30         True      False      False
# 31         True      False      False
# 32         True      False      False
# 33         True      False      False
# 34         True      False      False
# 35         True      False      False
# 36         True        n/a        n/a
# 37         True        n/a        n/a
# 38         True       True        n/a
# 39          n/a        n/a        n/a
# 40         True        n/a        n/a
# 41          n/a        n/a        n/a
# 42         True       True        n/a
# 43         True      False      False
# 44         True        n/a        n/a
# 45         True        n/a        n/a
# 46          n/a        n/a        n/a
# 47          n/a        n/a        n/a
# 48         True        n/a        n/a
# 49         True        n/a        n/a
# 50          n/a        n/a        n/a
# 51          n/a        n/a        n/a
# 52         True        n/a        n/a
# 53         True        n/a        n/a
# 54         True       True        n/a
# 55         True        n/a        n/a
# 56         True       True        n/a
# 57          n/a        n/a        n/a
# 58         True        n/a        n/a
# 59          n/a        n/a        n/a
#
#                                           website_url     business_status  \
# 0   https://maps.google.com/?cid=18195972309441806285         OPERATIONAL
# 1             https://www.facebook.com/peregrino1982/         OPERATIONAL
# 2   http://thelatinflavorindy.com/?utm_source=gmb&...         OPERATIONAL
# 3              https://store.kahero.co/milindopenjamo         OPERATIONAL
# 4    https://maps.google.com/?cid=8721236106944255517         OPERATIONAL
# 5     https://maps.google.com/?cid=798189214973396941         OPERATIONAL
# 6   https://antojitosguzmanfoodtruck1.business.sit...         OPERATIONAL
# 7    https://maps.google.com/?cid=5987304690148734817         OPERATIONAL
# 8   https://maps.google.com/?cid=12871198745142313123         OPERATIONAL
# 9   https://downtown-indy.clustertruck.com/menu?ut...         OPERATIONAL
# 10  https://maps.google.com/?cid=15116586037037737985         OPERATIONAL
# 11   https://maps.google.com/?cid=4690178681313906361         OPERATIONAL
# 12             https://www.elviejonfoodtruckindy.com/         OPERATIONAL
# 13  https://oasis-taco-truck.business.site/?utm_so...         OPERATIONAL
# 14                        http://mercersnightowl.com/         OPERATIONAL
# 15       https://www.instagram.com/tacopolisin/?hl=en         OPERATIONAL
# 16  https://maps.google.com/?cid=17942349421368134051         OPERATIONAL
# 17  https://maps.google.com/?cid=12907492761856827049         OPERATIONAL
# 10  39.764207 -86.211581
# 11  39.663167 -86.125934
# 12  39.809908 -86.221618
# 13  39.882723 -86.208302
# 14  39.761686 -86.157930
# 15  39.823742 -86.242286
# 16  39.698134 -86.185729
# 17  39.788288 -86.215306
# 18  39.802975 -86.013654
# 19  39.771133 -86.060388
# 20  39.818318 -86.226983
# 21  39.822919 -86.234423
# 22  39.761510 -86.149000
# 23  39.760846 -86.081233
# 24  39.779803 -86.273933
# 25  39.802479 -86.149918
# 26  39.826928 -85.992336
# 27  39.825104 -86.117761
# 28  39.768243 -86.110046
# 29  39.796611 -86.046448
# 30  39.773510 -86.010881
# 31  39.867510 -86.201931
# 32  39.754381 -86.244534
# 33  39.904795 -86.089632
# 34  39.823622 -86.246627
# 35  39.826668 -85.992260
# 36  39.707575 -86.143175
# 37  39.885640 -86.211436
# 38  39.747046 -86.270161
# 39  39.839196 -86.150672
# 40  39.767596 -86.186622
# 41  39.868366 -86.125702
# 42  39.765164 -86.205520
# 43  39.793719 -86.144535
# 44  39.780522 -86.216018
# 45  39.905476 -86.049086
# 46  39.722651 -86.157474
# 47  39.760304 -86.108891
# 48  39.751244 -86.197539
# 49  39.750540 -86.256950
# 50  39.827639 -85.989306
# 51  39.783716 -86.133762
# 52  39.819564 -86.046882
# 53  39.663710 -86.084526
# 54  39.780257 -86.143644
# 55  39.802975 -86.013654
# 56  39.704057 -86.148415
# 57  39.759592 -86.112215
# 58  39.802479 -86.149918
# 59  39.876044 -85.951620

# %% [markdown]
# ## Average rating for food trucks open on Saturday.

# %%
print("Average rating = ",round(food_truck_df[food_truck_df['sat_open'] == "Open"]['rating'].mean(),2))
# Out:
# Average rating =  4.35

# %% [markdown]
# ## Saturday Food Trucks Opening Hours

# %%
food_truck_df['sat_open_hr'].value_counts()
# Out:
# sat_open_hr
# n/a        18
# 11:00AM     8
# Closed      5
# 12:00PM     5
# 6:00PM      5
# 10:00AM     5
# 5:00PM      3
# 10:30AM     2
# 8:00AM      2
# 2:00PM      1
# 2:30PM      1
# 8:30PM      1
# 1:59PM      1
# 3:00PM      1
# 4:00PM      1
# 7:00PM      1
# Name: count, dtype: int64

# %% [markdown]
# ## Average rating for food trucks open on Sunday.

# %%
print("Average rating = ",round(food_truck_df[food_truck_df['sun_open'] == "Open"]['rating'].mean(),2))
# Out:
# Average rating =  4.29

# %% [markdown]
# ## Sunday Food Trucks Opening Hours

# %%
food_truck_df['sun_open_hr'].value_counts()
# Out:
# sun_open_hr
# Closed     18
# n/a        18
# 11:00AM     4
# 6:00PM      4
# 10:00AM     4
# 5:00PM      3
# 2:00PM      1
# 8:00AM      1
# 2:30PM      1
# 8:30PM      1
# 10:30AM     1
# 12:00PM     1
# 1:59PM      1
# 3:00PM      1
# 7:00PM      1
# Name: count, dtype: int64

# %% [markdown]
# We've observed that 18 additional restaurants remain closed on Sundays. Of these, 4 usually start their operations in the morning.

# %%
# Categorize food trucks based on their operational timings.

# Saturday Categories
sat_morning = food_truck_df.loc[food_truck_df['sat_open_hr'].str.contains("AM")]  # Open in Saturday morning.
sat_lunch = food_truck_df.loc[(food_truck_df['sat_open'] == "Open") & (food_truck_df['serve_lunch'] == True)]  # Open for Saturday lunch.
sat_dinner = food_truck_df.loc[(food_truck_df['sat_open'] == "Open") & (food_truck_df['serve_dinner'] == True)]  # Open for Saturday dinner.
sat_latenight = food_truck_df.loc[food_truck_df['sat_close_hr'].str.contains("AM")]  # Open till late Saturday night.

# Sunday Categories
sun_morning = food_truck_df.loc[food_truck_df['sun_open_hr'].str.contains("AM")]  # Open in Sunday morning.
sun_lunch = food_truck_df.loc[(food_truck_df['sun_open'] == "Open") & (food_truck_df['serve_lunch'] == True)]  # Open for Sunday lunch.
sun_dinner = food_truck_df.loc[(food_truck_df['sun_open'] == "Open") & (food_truck_df['serve_dinner'] == True)]  # Open for Sunday dinner.
sun_latenight = food_truck_df.loc[food_truck_df['sun_close_hr'].str.contains("AM")]  # Open till late Sunday night.

# %% [markdown]
# ## Function to generate a DataFrame containing details of 8 recommended food trucks for the weekend.

# %% [markdown]
# #### "drinks_wanted" parameter can be set to True if you're interested in places that offer beverages (default is False).

# %% [markdown]
# #### "preferred_rating" parameter allows you to specify a minimum rating for the food trucks (default threshold is 3.0).

# %%
def safe_sample(df, default=None):
    if not df.empty:
        return df.sample()
    else:
        return default
def get_weekend_food_trucks(sat_morning = sat_morning, sat_lunch = sat_lunch, sat_dinner = sat_dinner, sat_latenight = sat_latenight, 
                            sun_morning = sun_morning, sun_lunch = sun_lunch, sun_dinner = sun_dinner, sun_latenight = sun_latenight, 
                            drinks_wanted = False, preferred_rating = 3.0):
    schedule = pd.DataFrame(columns = sat_morning.columns)
    if (drinks_wanted == True):
        sat_dinner = sat_dinner[(sat_dinner['serve_beer'] == True) | (sat_dinner['serve_wine'] == True)]
        sun_dinner = sun_dinner[(sun_dinner['serve_beer'] == True) | (sun_dinner['serve_wine'] == True)]
    
    timeframes = [sat_morning, sat_lunch, sat_dinner, sat_latenight, 
                  sun_morning, sun_lunch, sun_dinner, sun_latenight]

    for timeframe in timeframes:
        timeframe = timeframe[(timeframe['rating'] >= preferred_rating) & (~timeframe['name'].isin(schedule['name']))]
        schedule = pd.concat([schedule, safe_sample(timeframe)])


    days = ['Saturday'] * 4 + ['Sunday'] * 4
    schedule['visit_day'] = days
    
    return schedule

# %% [markdown]
# ## Create Weekend Schedule

# %% [markdown]
# #### I have created 3 schedules

# %%
schedule1 = get_weekend_food_trucks(sat_morning, sat_lunch, sat_dinner, sat_latenight, 
                                   sun_morning, sun_lunch, sun_dinner, sun_latenight)
schedule2 = get_weekend_food_trucks(sat_morning, sat_lunch, sat_dinner, sat_latenight, 
                                   sun_morning, sun_lunch, sun_dinner, sun_latenight, 
                                   preferred_rating=4.5)
schedule3 = get_weekend_food_trucks(sat_morning, sat_lunch, sat_dinner, sat_latenight, 
                                   sun_morning, sun_lunch, sun_dinner, sun_latenight, 
                                   drinks_wanted=True, preferred_rating=4.0)

# %% [markdown]
# #### Extract detailed schedules for both Saturday and Sunday.

# %%
saturday1 = schedule1[schedule1['visit_day'] == 'Saturday']
sunday1 = schedule1[schedule1['visit_day'] == 'Sunday']

saturday2 = schedule2[schedule2['visit_day'] == 'Saturday']
sunday2 = schedule2[schedule2['visit_day'] == 'Sunday']

saturday3 = schedule3[schedule3['visit_day'] == 'Saturday']
sunday3 = schedule3[schedule3['visit_day'] == 'Sunday']

# %%
saturday1
# Out:
#                               name  \
# 56             Indy Porkopolis BBQ
# 1         Pico de Gallo Food Truck
# 6   Antojitos Guzman food truck #1
# 34              Restaurante Oaxaca
#
#                                               address  rating sat_open  \
# 56  4225 S East St, Indianapolis, IN 46227, United...     3.9     Open
# 1   3014 Lafayette Rd #3000, Indianapolis, IN 4622...     4.5     Open
# 6   4853 W 56th St, Indianapolis, IN 46254, United...     3.5     Open
# 34  5101 W 38th St, Indianapolis, IN 46224, United...     4.5     Open
#
#    sun_open sat_open_hr sat_close_hr sun_open_hr sun_close_hr serve_lunch  \
# 56   Closed     11:00AM       8:00PM      Closed       Closed        True
# 1      Open      5:00PM       1:00AM      5:00PM       1:00AM        True
# 6      Open      2:00PM       9:30PM      2:00PM       9:30PM        True
# 34   Closed      6:00PM       2:00AM      Closed       Closed        True
#
#    serve_dinner serve_beer serve_wine  \
# 56         True       True        n/a
# 1          True      False      False
# 6          True        n/a        n/a
# 34         True      False      False
#
#                                           website_url business_status  \
# 56                    http://www.indybbqcatering.com/     OPERATIONAL
# 1             https://www.facebook.com/peregrino1982/     OPERATIONAL
# 6   https://antojitosguzmanfoodtruck1.business.sit...     OPERATIONAL
# 34   https://maps.google.com/?cid=2467293794623917776     OPERATIONAL
#
#      latitude  longitude visit_day
# 56  39.704057 -86.148415  Saturday
# 1   39.809920 -86.221209  Saturday
# 6   39.852722 -86.241436  Saturday
# 34  39.823622 -86.246627  Saturday

# %% [markdown]
# #### Designate start and stop location. This is where the route will begin and end each day for the tour
# I have used Indianapolis Bus Station as start and stop location.

# %%
start_stop_location = "Indianapolis Bus Station"

# %% [markdown]
# #### Methods to get walking and driving directions.

# %%
def get_walk_results(df):
    results = map_client.directions(origin = start_stop_location,
                                         destination = start_stop_location,                                     
                                         waypoints = list(df['address']),
                                         mode='walking')
    time.sleep(2)
    return results

def get_drive_results(df):
    results = map_client.directions(origin = start_stop_location,
                                         destination = start_stop_location,                                     
                                         waypoints = list(df['address']),
                                         mode='driving')
    time.sleep(2)
    return results

# %%
sat1_walk_results = get_walk_results(saturday1)
sat1_drive_results = get_drive_results(saturday1)
sun1_walk_results = get_walk_results(sunday1)
sun1_drive_results = get_drive_results(sunday1)
sat2_walk_results = get_walk_results(saturday2)
sat2_drive_results = get_drive_results(saturday2)
sun2_walk_results = get_walk_results(sunday2)
sun2_drive_results = get_drive_results(sunday2)
sat3_walk_results = get_walk_results(saturday3)
sat3_drive_results = get_drive_results(saturday3)
sun3_walk_results = get_walk_results(sunday3)
sun3_drive_results = get_drive_results(sunday3)

# %% [markdown]
# ### Method to generate a DataFrame detailing transportation mode (walk or drive) for each segment of the food truck tour.

# %%
def decide_method(row):
    if float(row['walk_distance'][:-3]) <= 1.25:
        method = "walk"
    else:
        method = "drive"
    return method

# %%
def get_saturday_decide_df(df_walk, df_drive, saturday_df):
    """
    Generate a dataframe for Saturday's food truck visits, capturing walking and driving information.
    
    Parameters:
    - df_walk: DataFrame containing walking distances and times between food trucks.
    - df_drive: DataFrame containing driving distances and times between food trucks.
    - saturday_df: DataFrame containing Saturday's food truck details.
    
    Returns:
    - DataFrame with consolidated data.
    """
    start_location, start_address, end_location, end_address = [], [], [], []
    walk_distance_mi, walk_time_hr_min, walk_time_s = [], [], []
    drive_distance_mi, drive_time_hr_min, drive_time_s = [], [], []
    leg, rating, open_close, beer, wine = [], [], [], [], []
    for i in range(len(df_walk[0]['legs'])):
        leg.append(i+1)
        if (i == 0):
            start_location.append(start_stop_location)
            end_location.append(saturday_df['name'].iloc[i])
            rating.append(saturday_df['rating'].iloc[i])
            open_close.append('-'.join([saturday_df['sat_open_hr'].iloc[i],saturday_df['sat_close_hr'].iloc[i]]))
            beer.append(saturday_df['serve_beer'].iloc[i])
            wine.append(saturday_df['serve_wine'].iloc[i])
        elif (i == len(df_walk[0]['legs'])-1):
            end_location.append(start_stop_location)
            start_location.append(saturday_df['name'].iloc[i-1])
            rating.append('-')
            open_close.append('-')
            beer.append('-')
            wine.append('-')
        else:
            start_location.append(saturday_df['name'].iloc[i-1])
            end_location.append(saturday_df['name'].iloc[i])
            rating.append(saturday_df['rating'].iloc[i])
            open_close.append('-'.join([saturday_df['sat_open_hr'].iloc[i],saturday_df['sat_close_hr'].iloc[i]]))
            beer.append(saturday_df['serve_beer'].iloc[i])
            wine.append(saturday_df['serve_wine'].iloc[i])
            
        start_address.append(df_walk[0]['legs'][i]['start_address'])
        end_address.append(df_walk[0]['legs'][i]['end_address'])
        walk_distance_mi.append(df_walk[0]['legs'][i]['distance']['text'])
        walk_time_hr_min.append(df_walk[0]['legs'][i]['duration']['text'])
        walk_time_s.append(df_walk[0]['legs'][i]['duration']['value'])
        drive_distance_mi.append(df_drive[0]['legs'][i]['distance']['text'])
        drive_time_hr_min.append(df_drive[0]['legs'][i]['duration']['text'])
        drive_time_s.append(df_drive[0]['legs'][i]['duration']['value'])

    saturday_decide_dict = {'leg': leg, 'start_location': start_location, 'start_address': start_address, 'end_location':end_location, 'end_address': end_address, 
                            'walk_distance':walk_distance_mi, 'walk_time':walk_time_hr_min, 'walk_time_s':walk_time_s, 'drive_distance':drive_distance_mi,
                            'drive_time':drive_time_hr_min, 'drive_time_s': drive_time_s, 'end_location_rating':rating, 'hours': open_close, 
                            'serve_beer': beer, 'serve_wine': wine}
    # convert the dictionary to a DataFrame.
    saturday_decide_df = pd.DataFrame(saturday_decide_dict)   
    saturday_decide_df['method'] = saturday_decide_df.apply(decide_method, axis=1)
    
    return saturday_decide_df

def get_sunday_decide_df(df_walk, df_drive, sunday_df):
    """
    Generate a dataframe for Sunday's food truck visits, capturing walking and driving information.
    
    Parameters:
    - df_walk: DataFrame containing walking distances and times between food trucks.
    - df_drive: DataFrame containing driving distances and times between food trucks.
    - sunday_df: DataFrame containing Sunday's food truck details.
    
    Returns:
    - DataFrame with consolidated data.
    """
    start_location, start_address, end_location, end_address = [], [], [], []
    walk_distance_mi, walk_time_hr_min, walk_time_s = [], [], []
    drive_distance_mi, drive_time_hr_min, drive_time_s = [], [], []
    leg, rating, open_close, beer, wine = [], [], [], [], []
    for i in range(len(df_walk[0]['legs'])):
        leg.append(i+1)
        if (i == 0):
            start_location.append(start_stop_location)
            end_location.append(sunday_df['name'].iloc[i])
            rating.append(sunday_df['rating'].iloc[i])
            open_close.append('-'.join([sunday_df['sat_open_hr'].iloc[i],sunday_df['sat_close_hr'].iloc[i]]))
            beer.append(sunday_df['serve_beer'].iloc[i])
            wine.append(sunday_df['serve_wine'].iloc[i])
        elif (i == len(df_walk[0]['legs'])-1):
            end_location.append(start_stop_location)
            start_location.append(sunday_df['name'].iloc[i-1])
            rating.append("n/a")
            open_close.append('-')
            beer.append('-')
            wine.append('-')
        else:
            start_location.append(sunday_df['name'].iloc[i-1])
            end_location.append(sunday_df['name'].iloc[i])
            rating.append(sunday_df['rating'].iloc[i])
            open_close.append('-'.join([sunday_df['sat_open_hr'].iloc[i],sunday_df['sat_close_hr'].iloc[i]]))
            beer.append(sunday_df['serve_beer'].iloc[i])
            wine.append(sunday_df['serve_wine'].iloc[i])
        start_address.append(df_walk[0]['legs'][i]['start_address'])
        end_address.append(df_walk[0]['legs'][i]['end_address'])
        walk_distance_mi.append(df_walk[0]['legs'][i]['distance']['text'])
        walk_time_hr_min.append(df_walk[0]['legs'][i]['duration']['text'])
        walk_time_s.append(df_walk[0]['legs'][i]['duration']['value'])
        drive_distance_mi.append(df_drive[0]['legs'][i]['distance']['text'])
        drive_time_hr_min.append(df_drive[0]['legs'][i]['duration']['text'])
        drive_time_s.append(df_drive[0]['legs'][i]['duration']['value'])

    sunday_decide_dict = {'leg': leg, 'start_location': start_location, 'start_address': start_address, 'end_location':end_location, 'end_address': end_address, 
                          'walk_distance':walk_distance_mi, 'walk_time':walk_time_hr_min, 'walk_time_s':walk_time_s, 'drive_distance':drive_distance_mi,
                          'drive_time':drive_time_hr_min, 'drive_time_s': drive_time_s, 'end_location_rating':rating,  'hours': open_close, 
                          'serve_beer': beer, 'serve_wine': wine}
    # convert the dictionary to a DataFrame.
    sunday_decide_df = pd.DataFrame(sunday_decide_dict)   
    sunday_decide_df['method'] = sunday_decide_df.apply(decide_method, axis=1)
    
    return sunday_decide_df

# %%
saturday1_decide_df = get_saturday_decide_df(sat1_walk_results, sat1_drive_results, saturday1)
saturday2_decide_df = get_saturday_decide_df(sat2_walk_results, sat2_drive_results, saturday2)
saturday3_decide_df = get_saturday_decide_df(sat3_walk_results, sat3_drive_results, saturday3)

sunday1_decide_df = get_sunday_decide_df(sun1_walk_results, sun1_drive_results, sunday1)
sunday2_decide_df = get_sunday_decide_df(sun2_walk_results, sun2_drive_results, sunday2)
sunday3_decide_df = get_sunday_decide_df(sun3_walk_results, sun3_drive_results, sunday3)

# %%
saturday1_decide_df
# Out:
#    leg                  start_location  \
# 0    1        Indianapolis Bus Station
# 1    2             Indy Porkopolis BBQ
# 2    3        Pico de Gallo Food Truck
# 3    4  Antojitos Guzman food truck #1
# 4    5              Restaurante Oaxaca
#
#                                        start_address  \
# 0     350 S Illinois St, Indianapolis, IN 46225, USA
# 1        4225 S East St, Indianapolis, IN 46227, USA
# 2  3014 Lafayette Rd #3000, Indianapolis, IN 4622...
# 3        4853 W 56th St, Indianapolis, IN 46254, USA
# 4        5101 W 38th St, Indianapolis, IN 46254, USA
#
#                      end_location  \
# 0             Indy Porkopolis BBQ
# 1        Pico de Gallo Food Truck
# 2  Antojitos Guzman food truck #1
# 3              Restaurante Oaxaca
# 4        Indianapolis Bus Station
#
#                                          end_address walk_distance  \
# 0        4225 S East St, Indianapolis, IN 46227, USA        4.3 mi
# 1  3014 Lafayette Rd #3000, Indianapolis, IN 4622...        9.8 mi
# 2        4853 W 56th St, Indianapolis, IN 46254, USA        3.5 mi
# 3        5101 W 38th St, Indianapolis, IN 46254, USA        2.3 mi
# 4     350 S Illinois St, Indianapolis, IN 46225, USA        7.4 mi
#
#          walk_time  walk_time_s drive_distance drive_time  drive_time_s  \
# 0   1 hour 36 mins         5778         4.5 mi    12 mins           695
# 1  3 hours 38 mins        13095        17.4 mi    21 mins          1288
# 2   1 hour 19 mins         4721         3.5 mi    10 mins           594
# 3          52 mins         3108         2.4 mi     8 mins           468
# 4  2 hours 43 mins         9768         8.3 mi    16 mins           952
#
#   end_location_rating           hours serve_beer serve_wine method
# 0                 3.9  11:00AM-8:00PM       True        n/a  drive
# 1                 4.5   5:00PM-1:00AM      False      False  drive
# 2                 3.5   2:00PM-9:30PM        n/a        n/a  drive
# 3                 4.5   6:00PM-2:00AM      False      False  drive
# 4                   -               -          -          -  drive

# %% [markdown]
# ## Export Schedules to CSVs

# %%
def export_schedule(df, name):
    df = df.drop(['walk_time_s','drive_time_s'], axis=1)
    df.to_csv(name, index=False)

# %%
export_schedule(saturday1_decide_df,"ex_1_saturday.csv")
export_schedule(saturday2_decide_df,"ex_2_saturday.csv")
export_schedule(saturday3_decide_df,"ex_3_saturday.csv")
export_schedule(sunday1_decide_df,"ex_1_sunday.csv")
export_schedule(sunday2_decide_df,"ex_2_sunday.csv")
export_schedule(sunday3_decide_df,"ex_3_sunday.csv")

# %% [markdown]
# ## Map Generation

# %%
# Rapid API Key to access the services.
rapid_API_KEY = '4b0c6e5911mshadf5444dbe7c9e5p1d5938jsnb6e77c88cf7e'

def get_lat_long_from_address(address):
   locator = Nominatim(user_agent='http://localhost:8888/lab',timeout=100) # define a geolocator instance using the Nominatim service.
   location = locator.geocode(address) # use the geolocator to geocode the address.
   return location.latitude, location.longitude

def get_directions_response(lat1, long1, lat2, long2, mode='drive'):
   url = "https://route-and-directions.p.rapidapi.com/v1/routing" # Endpoint for the routing API
   key = rapid_API_KEY
   host = "route-and-directions.p.rapidapi.com"
   headers = {"X-RapidAPI-Key": key, "X-RapidAPI-Host": host}
   querystring = {"waypoints":f"{str(lat1)},{str(long1)}|{str(lat2)},{str(long2)}","mode":mode}
   # send a GET request to the API and retrieve the response.
   response = requests.request("GET", url, headers=headers, params=querystring)
   return response

# %%
def create_map(day_schedule):
    # create a list of addresses for the day's schedule, starting with the starting address.
    addresses = [day_schedule['start_address'][0]]
    for i in range(len(day_schedule['start_address'])):
        addresses.append(day_schedule['end_address'][i])
        
    # convert addresses to latitude and longitude coordinates.
    lat_lons = []
    for addr in addresses:
        try:
            lat_lons.append(get_lat_long_from_address(addr))
        except:
            print("NOTE: address:", addr," not found")
        time.sleep(3) # sleep to prevent overloading APIs or services.
        
    # get driving directions between each consecutive latitude-longitude pair.    
    responses = []
    for n in range(len(lat_lons)-1):
        lat1, lon1, lat2, lon2 = lat_lons[n][0], lat_lons[n][1], lat_lons[n+1][0], lat_lons[n+1][1]
        response = get_directions_response(lat1, lon1, lat2, lon2, mode='drive')
        responses.append(response)
        time.sleep(3) # sleep to prevent overloading APIs or services.
    
    # create a folium map and plot the route.
    m = folium.Map()
    df = pd.DataFrame()
    
    for point in lat_lons: # add markers for the locations on the map.
        folium.Marker(point).add_to(m)
    
    for response in responses: # add the driving routes on the map.
        mls = response.json()['features'][0]['geometry']['coordinates']
        points = [(i[1], i[0]) for i in mls[0]]
        folium.PolyLine(points, weight=5, opacity=1).add_to(m)
        temp = pd.DataFrame(mls[0]).rename(columns={0:'Lon', 1:'Lat'})[['Lat', 'Lon']]
        df = pd.concat([df, temp])
        
    # adjust the zoom to fit the route.
    sw = df[['Lat', 'Lon']].min().values.tolist()
    sw = [sw[0]-0.0005, sw[1]-0.0005]
    ne = df[['Lat', 'Lon']].max().values.tolist()
    ne = [ne[0]+0.0005, ne[1]+0.0005]
    m.fit_bounds([sw, ne])
    return m

def save_map_png(m,name):
    img_data = m._to_png(5)
    img = Image.open(io.BytesIO(img_data))
    img.save(name + '.png')

# %% [markdown]
# ## Example 1 maps

# %%
m = create_map(saturday1_decide_df)
m.save('saturday1_map.html')
m
# Out:
# NOTE: address: 3014 Lafayette Rd #3000, Indianapolis, IN 46222, USA  not found
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bb66a8165a1e9b2b00de3adce4255c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bb66a8165a1e9b2b00de3adce4255c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bb66a8165a1e9b2b00de3adce4255c8 = L.map(
#                 &quot;map_3bb66a8165a1e9b2b00de3adce4255c8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2459c23ab2c8e22c2e993b656655420a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3bb66a8165a1e9b2b00de3adce4255c8);
#
#
#             var marker_d681c47dc308419a6cd6a59340df7273 = L.marker(
#                 [39.7623048, -86.1596319],
#                 {}
#             ).addTo(map_3bb66a8165a1e9b2b00de3adce4255c8);
#
#
#             var marker_fc614b56c7c668ffd9a765bf04cbca9e = L.marker(
#                 [39.7040217, -86.14840944325397],
#                 {}
#             ).addTo(map_3bb66a8165a1e9b2b00de3adce4255c8);
#
#
#             var marker_cb57a2358d0eeb494b14988c2ebf97a4 = L.marker(
#                 [39.8527172, -86.24136094287257],
#                 {}
#             ).addTo(map_3bb66a8165a1e9b2b00de3adce4255c8);
#
#
#             var marker_f29b76ec16bb3a0141102d7e408cee30 = L.marker(
#                 [39.82275595, -86.24578131268535],
#                 {}
#             ).addTo(map_3bb66a8165a1e9b2b00de3adce4255c8);
#
#
#             var marker_4ab72ec7f80735dcbcf20479c4db8afa = L.marker(
#                 [39.7623048, -86.1596319],
#                 {}
#             ).addTo(map